# %% [markdown]
# Question 1

# %%
total-marks=100
2nd-position    # variable name cannot be started from number i.e 1,2,3
student name = shamsa
class= m.phil     #valid used for many things
-user-id          #valid
pass            #it is reserved keyword
user$amount    # special symbol cannot be use in variable name
is-enrolled    # invalid
print(2nd-position)
# Out:
#   File "/tmp/ipykernel_1028/4087344514.py", line 2
#     2nd-position
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Question 2

# %%
score = 75
Score = 90
SCORE = 100
print(score)
print(Score)
print(SCORE)
# Out:
# 75
# 90
# 100

# %% [markdown]
# part a answer
# no it does not overwrite because it is case sensitive and these are 3 different variable name

# %% [markdown]
# part b

# %%
first-name = "Ahmed"
print(First-Name)
# Out:
#   File "/tmp/ipykernel_1028/948349834.py", line 1
#     first-name = "Ahmed"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# answer
# First-Name variable is not defined above and python is case sensitive

# %% [markdown]
# Section B Question 3
# Part a
# 5000  int
# 3.85 float
# "CS-101"    str
# True   bool
# "True"   str

# %% [markdown]
# Part b
# answer

# %%
student_name = "shamsa"
student_Age =27
student_CGPA = 3.95
Enrollment_status = True
print(student_name)
# Out:
# shamsa

# %% [markdown]
# Question 4
# answer

# %%
item_name = "sugar"
unit_price = 190.5
quantity_purchased = 3
tax_status = True
subtotal = 190.5 *3
print(subtotal)
final_total = subtotal +(subtotal*0.05)
print(final_total)
# Out:
# 571.5
# 600.075

# %% [markdown]
# section c
# Question 5

# %%
student_name = "Ali Khan"
course_name = "python"
total_marks = 95
print("student" +student_name + "has score" + str(total_marks)+ "marks in python")
print("student" ,student_name ,"has score" ,total_marks , "in python")
print(f'student{student_name} has score {total_marks} in python')
# Out:
# studentAli Khanhas score95marks in python
# student Ali Khan has score 95 in python
# studentAli Khan has score 95 in python

# %% [markdown]
# Question 6

# %%
employee_name = "Ahmed"
job_title = "manger"
experience_years = 3
monthly_salary = 1000
is_regular_employee = True
print(f'"Employee Name "   : {employee_name} \n"Job Title"        : {job_title} \n"Total Experience  : {experience_years}\n"Monthl Salary"    :${monthly_salary}\n"Regular Employee  :{is_regular_employee}')
# Out:
# "Employee Name "   : Ahmed
# "Job Title"        : manger
# "Total Experience  : 3
# "Monthl Salary"    :$1000
# "Regular Employee  :True

# %% [markdown]
# bounas Question

# %%
num_first = 10
num_second = 20

print(f' before swapping num_first has value {num_first} and second_num has value {num_second}')
print (f' after swapping num_first has value {num_second} and num_second has value {num_first}' )
#another method
print (f' before swappig num_first = {num_first} , num_second = {num_second}' )
print (f' after swappig num_first = {num_second} , num_second = {num_first}' )
# Out:
#  before swapping num_first has value 10 and second_num has value 20
#  after swapping num_first has value 20 and num_second has value 10
#  before swappig num_first = 10 , num_second = 20
#  after swappig num_first = 20 , num_second = 10
